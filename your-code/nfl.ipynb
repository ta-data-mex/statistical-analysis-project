# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time 


#table_NFL = pd.read_html('https://www.nfl.com/stats/team-stats/offense/passing/2021/reg/all')

# %%
años=["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"]
passing_names = []
rushing_names = []
scoring_names = []
passingd_names = []
rushingd_names = []
scoringd_names = []
Fumbles_names = []
Interceptions_names = []

passing = 'https://www.nfl.com/stats/team-stats/offense/passing/2021/reg/all'
rushing = 'https://www.nfl.com/stats/team-stats/offense/rushing/2000/reg/all'
scoring = 'https://www.nfl.com/stats/team-stats/offense/scoring/2000/reg/all'

passingd = 'https://www.nfl.com/stats/team-stats/defense/passing/2000/reg/all'
rushingd = 'https://www.nfl.com/stats/team-stats/defense/rushing/2000/reg/all'
scoringd = 'https://www.nfl.com/stats/team-stats/defense/scoring/2000/reg/all'
Fumbles = 'https://www.nfl.com/stats/team-stats/defense/fumbles/2000/reg/all'
Interceptions = 'https://www.nfl.com/stats/team-stats/defense/interceptions/2000/reg/all'

#table_NFL[0]
j =0
for i in años:
    passing_names.append(pd.read_html('https://www.nfl.com/stats/team-stats/offense/passing/' + i + '/reg/all'))
    #passing_names[j]['Year'] = i
    
    rushing_names.append(pd.read_html('https://www.nfl.com/stats/team-stats/offense/rushing/' + i + '/reg/all'))
    #rushing_names[j]['Year'] = i
    
    scoring_names.append(pd.read_html('https://www.nfl.com/stats/team-stats/offense/scoring/' + i + '/reg/all'))
    #scoring_names[j]['Year'] = i
    
    passingd_names.append(pd.read_html('https://www.nfl.com/stats/team-stats/defense/passing/' + i + '/reg/all'))
    #passingd_names[j]['Year'] = i
    
    rushingd_names.append(pd.read_html('https://www.nfl.com/stats/team-stats/defense/rushing/' + i + '/reg/all')) 
    #rushingd_names[j]['Year'] = i
    
    scoringd_names.append(pd.read_html('https://www.nfl.com/stats/team-stats/defense/scoring/' + i + '/reg/all'))
    #scoringd_names[j]['Year'] = i
    
    Fumbles_names.append(pd.read_html('https://www.nfl.com/stats/team-stats/defense/fumbles/' + i + '/reg/all'))
    #Fumbles_names[j]['Year'] = i
    
    Interceptions_names.append(pd.read_html('https://www.nfl.com/stats/team-stats/defense/interceptions/' + i + '/reg/all'))
    #Interceptions_names[j]['Year'] = i
    time.sleep(10)
    j = j + 1

# %%
años=[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
j = 0
for i in años:
    passing_names[j][0]['Years'] = i 
    rushing_names[j][0]['Years'] = i 
    scoring_names[j][0]['Years'] = i 
    passingd_names[j][0]['Years'] = i 
    rushingd_names[j][0]['Years'] = i 
    scoringd_names[j][0]['Years'] = i 
    Fumbles_names[j][0]['Years'] = i 
    Interceptions_names[j][0]['Years'] = i 
    j = j + 1

# %%
passing_t = pd.DataFrame()
rushing_t = pd.DataFrame()
scoring_t = pd.DataFrame()
passingd_t = pd.DataFrame()
rushingd_t = pd.DataFrame()
scoringd_t = pd.DataFrame()
Fumbles_t = pd.DataFrame()
Interceptions_t = pd.DataFrame()

j = 0
for i in años:
    passing_t = pd.concat([passing_t, passing_names[j][0]]) 
    rushing_t = pd.concat([rushing_t, rushing_names[j][0]]) 
    scoring_t = pd.concat([scoring_t, scoring_names[j][0]]) 
    passingd_t = pd.concat([passingd_t, passingd_names[j][0]]) 
    rushingd_t = pd.concat([rushingd_t, rushingd_names[j][0]]) 
    scoringd_t = pd.concat([scoringd_t, scoringd_names[j][0]]) 
    Fumbles_t = pd.concat([Fumbles_t, Fumbles_names[j][0]]) 
    Interceptions_t = pd.concat([Interceptions_t, Interceptions_names[j][0]]) 
    j = j + 1

# %%
#passing_t 
passing_t.to_csv('Passing_Offense.csv')
rushing_t.to_csv('Rushing_Offense.csv')
scoring_t.to_csv('Scoring_Offense.csv')
passingd_t.to_csv('Paasing_Deff.csv')
rushingd_t.to_csv('Rushing_Deff.csv')
scoringd_t.to_csv('Scoring_Deff.csv')
Fumbles_t.to_csv('Fumbles.csv')
Interceptions_t.to_csv('Interceptions.csv')

# %%
# Out:
#                     Team  Att  Cmp  Cmp_%  Yds/Att  Pass_Yds  TD  INT  Rate  \
# 0       RedskinsRedskins  561  343   61.1      6.9      3892  18   21  77.0
# 1   BuccaneersBuccaneers  433  237   54.7      6.5      2824  18   13  76.2
# 2       SeahawksSeahawks  507  308   60.7      6.3      3198  21   21  75.5
# 3             49ers49ers  583  366   62.8      7.5      4400  32   10  97.0
# 4       ChargersChargers  578  311   53.8      6.1      3540  19   30  61.8
# ..                   ...  ...  ...    ...      ...       ...  ..  ...   ...
# 27            BearsBears  542  332   61.3      6.7      3635  16   20  75.5
# 28      PanthersPanthers  599  348   58.1      6.0      3573  14   21  68.5
# 29            BillsBills  655  415   63.4      6.8      4450  36   16  91.3
# 30          RavensRavens  611  396   64.8      7.0      4267  21   18  84.4
# 31        FalconsFalcons  573  377   65.8      7.0      3987  20   15  86.6
#
#     1st  1st%  20+  40+  Lng  Sck  SckY  Years
# ...

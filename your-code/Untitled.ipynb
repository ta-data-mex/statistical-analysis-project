# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('train.csv')
data.shape
# Out:
# (1460, 81)

# %%
#getting rid of all the columns that have too many NaN

print(data.isna().sum().sort_values(ascending=False))
data.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'LotFrontage'], 
          inplace=True)

# %%
#List of other variables that have a considerable number of NaN but I want to replace with something
data.isna().sum().sort_values(ascending=False)

con_na = ['GarageType', 
          'GarageYrBlt', 
          'GarageFinish', 
          'GarageCond', 
          'GarageQual', 
          'BsmtExposure', 
          'BsmtFinType2', 
          'BsmtFinType1', 
          'BsmtCond', 
          'BsmtQual']

#Removed GarageYrBlt from the list as it is the only numerical field, I will treat it differently
con_na.remove('GarageYrBlt')

# %%
#Fillna for all the variables in the list with 'NA'
data[con_na] = data[con_na].fillna('NA')
#Fillna for GarageYrBlt with 0
data['GarageYrBlt'] = data['GarageYrBlt'].fillna(0)

# %%
#Filling other variables that have less NaN
print(data.isna().sum().sort_values(ascending=False))
data['MasVnrType'] = data['MasVnrType'].fillna('None')
data['MasVnrArea'] = data['MasVnrArea'].fillna(0.0)
data['Electrical'] = data['Electrical'].fillna('NA')

# %%
#Now we have no values missing
data.isna().sum().sort_values(ascending=False).head()
# Out:
# TotalPorchSF    0
# SalePrice       0
# RoofStyle       0
# RoofMatl        0
# Exterior1st     0
# dtype: int64

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl  ...             0         0           0        0
# 1       FR2       Gtl  ...             0         0           0        0
# 2    Inside       Gtl  ...             0         0           0        0
# 3    Corner       Gtl  ...           272         0           0        0
# 4       FR2       Gtl  ...             0         0           0        0
#
#   MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0       0       2    2008        WD         Normal    208500
# 1       0       5    2007        WD         Normal    181500
# 2       0       9    2008        WD         Normal    223500
# 3       0       2    2006        WD        Abnorml    140000
# 4       0      12    2008        WD         Normal    250000
#
# [5 rows x 75 columns]

# %%
#Most of the properties have only one type of Porch, and we have 4 columns for the area of each
#Type of porch... So I will create a TotalPorchSF column with the sum of the other 4
#And drop the other for
data[['OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch']].head(20)
# Out:
#     OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch
# 0            61              0          0            0
# 1             0              0          0            0
# 2            42              0          0            0
# 3            35            272          0            0
# 4            84              0          0            0
# 5            30              0        320            0
# 6            57              0          0            0
# 7           204            228          0            0
# 8             0            205          0            0
# 9             4              0          0            0
# 10            0              0          0            0
# 11           21              0          0            0
# 12            0              0          0          176
# 13           33              0          0            0
# 14          213            176          0            0
# 15          112              0          0            0
# 16            0              0          0            0
# 17            0              0          0            0
# 18          102              0          0            0
# 19            0              0          0            0

# %%
data['TotalPorchSF'] = data['OpenPorchSF'] + data['EnclosedPorch'] + data['3SsnPorch'] + data['ScreenPorch']

# %%
data.drop(columns=['OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch'], inplace=True)

# %%
#We have 4 columns that give us information about basement area:
#BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF
#The first 2 are the area of finished basement, the 3rd the area of unfinished basement
#And the 4th is the total.
#In order to have less columns, we will compute the % of finished basement area
#((BsmtFinSF1+BsmtFinSF2)/TotalBsmtSF)
#After that, we will eliminate BsmtFinSF1, BsmtFinSF2, BsmtUnfSF,

data['PercentBsmtFin'] = (data.BsmtFinSF1+data.BsmtFinSF2)/data.TotalBsmtSF
data.drop(columns=['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF'], inplace=True)
# Out:
# 37

# %%
#we had 37 calculations that could not be made (the ones that have no basement)
#We will replace them with 0
data['PercentBsmtFin'].isna().sum()
data['PercentBsmtFin'] = data['PercentBsmtFin'].fillna(0)

# %%
#Now, we have 4 variables that describe the number of bathrooms in each property
#Though it gives us a lot of detail, we could have only one variable for that
data['TotalBath'] = data.BsmtFullBath + data.BsmtHalfBath + data.FullBath + data.HalfBath
data.drop(columns=['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath'], inplace=True)

# %%
#All columns that are categorical but have an implicit scale in it, 
#I will convert in only one column with a numerical scale

#First, let's separate those columns and check what is their scale
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice', 'TotalPorchSF', 'PercentBsmtFin'],
#       dtype='object')

# %%
#Categorical Variables that have an implicit scale
cat_scale = ['ExterQual', 
             'ExterCond', 
             'BsmtQual', 
             'BsmtCond', 
             'BsmtExposure', 
             'BsmtFinType1', 
             'BsmtFinType2', 
             'HeatingQC', 
             'Functional', 
             'GarageFinish', 
             'GarageQual', 
             'GarageCond']
data[cat_scale]
# Out:
#      ExterQual ExterCond BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0           Gd        TA       Gd       TA           No          GLQ
# 1           TA        TA       Gd       TA           Gd          ALQ
# 2           Gd        TA       Gd       TA           Mn          GLQ
# 3           TA        TA       TA       Gd           No          ALQ
# 4           Gd        TA       Gd       TA           Av          GLQ
# 5           TA        TA       Gd       TA           No          GLQ
# 6           Gd        TA       Ex       TA           Av          GLQ
# 7           TA        TA       Gd       TA           Mn          ALQ
# 8           TA        TA       TA       TA           No          Unf
# 9           TA        TA       TA       TA           No          GLQ
# 10          TA        TA       TA       TA           No          Rec
# 11          Ex        TA       Ex       TA           No          GLQ
# 12          TA        TA       TA       TA           No          ALQ
# 13          Gd        TA       Gd       TA           Av          Unf
# 14          TA        TA       TA       TA           No          BLQ
# 15          TA        TA       TA       TA           No          Unf
# 16          TA        TA       TA       TA           No          ALQ
# 17          TA        TA       NA       NA           NA           NA
# 18          TA        TA       TA       TA           No          GLQ
# 19          TA        TA       TA       TA           No          LwQ
# 20          Gd        TA       Ex       TA           Av          Unf
# 21          TA        TA       TA       TA           No          Unf
# 22          Gd        TA       Gd       TA           No          Unf
# 23          TA        TA       Gd       TA           No          GLQ
# 24          TA        Gd       TA       TA           Mn          Rec
# 25          Gd        TA       Gd       TA           No          Unf
# 26          TA        TA       TA       TA           Mn          BLQ
# 27          Gd        TA       Ex       TA           No          GLQ
# 28          TA        TA       TA       TA           Gd          BLQ
# 29          TA        TA       TA       TA           No          Unf
# ...        ...       ...      ...      ...          ...          ...
# 1430        Gd        TA       Gd       Gd           Av          Unf
# 1431        TA        TA       Gd       TA           No          LwQ
# 1432        TA        TA       TA       TA           No          Unf
# 1433        TA        TA       Gd       TA           No          Unf
# 1434        TA        TA       TA       TA           No          ALQ
# 1435        Gd        Gd       TA       TA           No          Unf
# 1436        TA        TA       TA       TA           No          ALQ
# 1437        Ex        TA       Ex       TA           Av          GLQ
# 1438        TA        TA       TA       TA           No          GLQ
# 1439        TA        TA       TA       TA           No          GLQ
# 1440        TA        TA       Ex       TA           No          Unf
# 1441        Gd        TA       Gd       TA           Av          GLQ
# 1442        Ex        TA       Ex       TA           Av          GLQ
# 1443        TA        TA       TA       TA           No          Unf
# 1444        Gd        TA       Gd       TA           Av          Unf
# 1445        TA        TA       TA       TA           Gd          LwQ
# 1446        TA        TA       TA       TA           No          Rec
# 1447        Gd        TA       Gd       TA           No          GLQ
# 1448        TA        TA       Fa       TA           No          Unf
# 1449        TA        TA       Gd       TA           Av          GLQ
# 1450        TA        TA       Gd       TA           No          Unf
# 1451        Gd        TA       Gd       TA           No          Unf
# 1452        TA        TA       Gd       TA           Gd          GLQ
# 1453        TA        TA       Gd       TA           No          Unf
# 1454        Gd        TA       Gd       TA           No          GLQ
# 1455        TA        TA       Gd       TA           No          Unf
# 1456        TA        TA       Gd       TA           No          ALQ
# 1457        Ex        Gd       TA       Gd           No          GLQ
# 1458        TA        TA       TA       TA           Mn          GLQ
# 1459        Gd        TA       TA       TA           No          BLQ
#
#      BsmtFinType2 HeatingQC Functional GarageFinish GarageQual GarageCond
# 0             Unf        Ex        Typ          RFn         TA         TA
# 1             Unf        Ex        Typ          RFn         TA         TA
# 2             Unf        Ex        Typ          RFn         TA         TA
# 3             Unf        Gd        Typ          Unf         TA         TA
# 4             Unf        Ex        Typ          RFn         TA         TA
# 5             Unf        Ex        Typ          Unf         TA         TA
# 6             Unf        Ex        Typ          RFn         TA         TA
# 7             BLQ        Ex        Typ          RFn         TA         TA
# 8             Unf        Gd       Min1          Unf         Fa         TA
# 9             Unf        Ex        Typ          RFn         Gd         TA
# 10            Unf        Ex        Typ          Unf         TA         TA
# 11            Unf        Ex        Typ          Fin         TA         TA
# 12            Unf        TA        Typ          Unf         TA         TA
# 13            Unf        Ex        Typ          RFn         TA         TA
# 14            Unf        TA        Typ          RFn         TA         TA
# 15            Unf        Ex        Typ          Unf         TA         TA
# 16            Unf        Ex        Typ          Fin         TA         TA
# 17             NA        TA        Typ          Unf         TA         TA
# 18            Unf        Ex        Typ          Unf         TA         TA
# 19            Unf        TA       Min1          Unf         TA         TA
# 20            Unf        Ex        Typ          RFn         TA         TA
# 21            Unf        Ex        Typ          Unf         TA         TA
# 22            Unf        Ex        Typ          RFn         TA         TA
# 23            Unf        TA        Typ          Unf         TA         TA
# 24            ALQ        Ex        Typ          Unf         TA         TA
# 25            Unf        Ex        Typ          RFn         TA         TA
# 26            Rec        TA        Typ          Unf         TA         TA
# 27            Unf        Ex        Typ          RFn         TA         TA
# 28            Unf        TA        Typ          RFn         TA         TA
# 29            Unf        Fa        Typ          Unf         Fa         TA
# ...           ...       ...        ...          ...        ...        ...
# 1430          Unf        Ex        Typ          Fin         TA         TA
# 1431          Unf        TA        Typ          RFn         TA         TA
# 1432          Unf        TA        Typ          Unf         Fa         Fa
# 1433          Unf        Ex        Typ          Fin         TA         TA
# 1434          Unf        Fa        Typ          RFn         TA         TA
# 1435          Unf        TA        Typ          RFn         TA         TA
# 1436          Unf        TA        Typ          Unf         TA         TA
# 1437          Unf        Ex        Typ          Fin         TA         TA
# 1438          Unf        TA        Typ          Unf         TA         TA
# 1439          Rec        TA        Typ          RFn         TA         TA
# 1440          Unf        Fa       Min1          Fin         TA         TA
# 1441          Unf        Ex        Typ          RFn         TA         TA
# 1442          Unf        Ex        Typ          Fin         TA         TA
# 1443          Unf        Fa        Typ          Unf         Fa         Po
# 1444          Unf        Ex        Typ          RFn         TA         TA
# 1445          Rec        Gd        Typ          Unf         TA         TA
# 1446          Unf        TA        Typ          Unf         TA         TA
# 1447          Unf        Ex        Typ          RFn         TA         TA
# 1448          Unf        Gd       Min2          Unf         Fa         TA
# 1449          Unf        Ex        Typ           NA         NA         NA
# 1450          Unf        TA        Typ           NA         NA         NA
# 1451          Unf        Ex        Typ          Fin         TA         TA
# 1452          Unf        Gd        Typ          Fin         TA         TA
# 1453          Unf        Ex        Typ           NA         NA         NA
# 1454          Unf        Ex        Typ          RFn         TA         TA
# 1455          Unf        Ex        Typ          RFn         TA         TA
# 1456          Rec        TA       Min1          Unf         TA         TA
# 1457          Unf        Ex        Typ          RFn         TA         TA
# 1458          Rec        Gd        Typ          Unf         TA         TA
# 1459          LwQ        Gd        Typ          Fin         TA         TA
#
# [1460 rows x 12 columns]

# %%
cut_1 = {'NA':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5} #'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'HeatingQC', 'GarageQual', 'GarageCond'
cut_2 = {'NA':0, 'Unf':1, 'LwQ':2, 'Rec':3, 'BLQ':4, 'ALQ':5, 'GLQ':6} #'BsmtFinType1', 'BsmtFinType2'
cut_3 = {'NA':0, 'No':1, 'Mn':2, 'Av':3, 'Gd':4} #'BsmtExposure'
cut_4 = {'Sal':0, 'Sev':1, 'Maj2':2, 'Maj1':3, 'Mod':4, 'Min2':5, 'Min1':6, 'Typ':7} #'Functional'
cut_5 = {'NA':0, 'Unf':1, 'RFn':2, 'Fin':3} #'GarageFinish'

def labeling(s, dic):
    return dic[s]

# %%
col_cut_1 = ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'HeatingQC', 'GarageQual', 'GarageCond']
col_cut_2 = ['BsmtFinType1', 'BsmtFinType2']

for el in col_cut_1:
    data[el] = data[el].apply(lambda x: labeling(x, cut_1))

for el in col_cut_2:
    data[el] = data[el].apply(lambda x: labeling(x, cut_2))

data['BsmtExposure'] = data['BsmtExposure'].apply(lambda x: labeling(x, cut_3))
data['Functional'] = data['Functional'].apply(lambda x: labeling(x, cut_4))
data['GarageFinish'] = data['GarageFinish'].apply(lambda x: labeling(x, cut_5))

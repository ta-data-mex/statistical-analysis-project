# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm
from pylab import rcParams

# holt winters 
# single exponential smoothing
from statsmodels.tsa.holtwinters import SimpleExpSmoothing   
# double and triple exponential smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
google = pd.read_csv('GOOG.csv',index_col='Date', parse_dates=True)
google
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-10-06  1475.579956  1486.760010  1448.589966  1453.439941  1453.439941
# 2020-10-07  1464.290039  1468.959961  1436.000000  1460.290039  1460.290039
# 2020-10-08  1465.089966  1490.000000  1465.089966  1485.930054  1485.930054
# 2020-10-09  1494.699951  1516.520020  1489.449951  1515.219971  1515.219971
# 2020-10-12  1543.000000  1593.859985  1532.569946  1569.150024  1569.150024
# ...                 ...          ...          ...          ...          ...
# 2021-09-30  2686.500000  2711.800049  2660.000000  2665.310059  2665.310059
# 2021-10-01  2671.090088  2741.419922  2667.550049  2729.250000  2729.250000
# 2021-10-04  2713.989990  2714.000000  2623.330078  2675.300049  2675.300049
# 2021-10-05  2680.000000  2747.239990  2680.000000  2723.540039  2723.540039
# 2021-10-06  2692.510010  2757.000000  2689.936523  2747.080078  2747.080078
#
#              Volume
# Date
# 2020-10-06  1245400
# ...

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2020-10-06 to 2021-10-06
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       253 non-null    float64
#  1   High       253 non-null    float64
#  2   Low        253 non-null    float64
#  3   Close      253 non-null    float64
#  4   Adj Close  253 non-null    float64
#  5   Volume     253 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %%
google.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-10-06  1475.579956  1486.760010  1448.589966  1453.439941  1453.439941
# 2020-10-07  1464.290039  1468.959961  1436.000000  1460.290039  1460.290039
# 2020-10-08  1465.089966  1490.000000  1465.089966  1485.930054  1485.930054
# 2020-10-09  1494.699951  1516.520020  1489.449951  1515.219971  1515.219971
# 2020-10-12  1543.000000  1593.859985  1532.569946  1569.150024  1569.150024
#
#              Volume
# Date
# 2020-10-06  1245400
# 2020-10-07  1746200
# 2020-10-08  1187800
# 2020-10-09  1435300
# 2020-10-12  2482600

# %%
google.High.plot.hist(); #Los datos no siguen una distribución normal

# %%
sns.set_style("darkgrid")
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
plt.title('Google History 2020-2021', fontsize=25)
sns.lineplot(google.index,google.High, color='c');

#google.High.plot(figsize=[15, 6], color='y');
# Out:
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
apple = pd.read_csv('AAPL2020-2021.csv')
apple
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-10-06  115.699997  116.120003  112.250000  113.160004  112.436829
# 1    2020-10-07  114.620003  115.550003  114.129997  115.080002  114.344566
# 2    2020-10-08  116.250000  116.400002  114.589996  114.970001  114.235260
# 3    2020-10-09  115.279999  117.000000  114.919998  116.970001  116.222481
# 4    2020-10-12  120.059998  125.180000  119.279999  124.400002  123.604996
# ..          ...         ...         ...         ...         ...         ...
# 248  2021-09-30  143.660004  144.380005  141.279999  141.500000  141.500000
# 249  2021-10-01  141.899994  142.919998  139.110001  142.649994  142.649994
# 250  2021-10-04  141.759995  142.210007  138.270004  139.139999  139.139999
# 251  2021-10-05  139.490005  142.240005  139.360001  141.110001  141.110001
# 252  2021-10-06  139.470001  142.149994  138.369995  142.000000  142.000000
#
#         Volume
# 0    161498200
# 1     96849000
# ...

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       253 non-null    object
#  1   Open       253 non-null    float64
#  2   High       253 non-null    float64
#  3   Low        253 non-null    float64
#  4   Close      253 non-null    float64
#  5   Adj Close  253 non-null    float64
#  6   Volume     253 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 14.0+ KB

# %%
apple['Date'] = pd.to_datetime(apple['Date'])
apple
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-10-06  115.699997  116.120003  112.250000  113.160004  112.436829
# 1   2020-10-07  114.620003  115.550003  114.129997  115.080002  114.344566
# 2   2020-10-08  116.250000  116.400002  114.589996  114.970001  114.235260
# 3   2020-10-09  115.279999  117.000000  114.919998  116.970001  116.222481
# 4   2020-10-12  120.059998  125.180000  119.279999  124.400002  123.604996
# ..         ...         ...         ...         ...         ...         ...
# 248 2021-09-30  143.660004  144.380005  141.279999  141.500000  141.500000
# 249 2021-10-01  141.899994  142.919998  139.110001  142.649994  142.649994
# 250 2021-10-04  141.759995  142.210007  138.270004  139.139999  139.139999
# 251 2021-10-05  139.490005  142.240005  139.360001  141.110001  141.110001
# 252 2021-10-06  139.470001  142.149994  138.369995  142.000000  142.000000
#
#         Volume
# 0    161498200
# 1     96849000
# 2     83477200
# ...

# %%
apple.set_index('Date',inplace=True)
apple.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-10-06  115.699997  116.120003  112.250000  113.160004  112.436829
# 2020-10-07  114.620003  115.550003  114.129997  115.080002  114.344566
# 2020-10-08  116.250000  116.400002  114.589996  114.970001  114.235260
# 2020-10-09  115.279999  117.000000  114.919998  116.970001  116.222481
# 2020-10-12  120.059998  125.180000  119.279999  124.400002  123.604996
#
#                Volume
# Date
# 2020-10-06  161498200
# 2020-10-07   96849000
# 2020-10-08   83477200
# 2020-10-09  100506900
# 2020-10-12  240226800

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
plt.title('Apple History 2020-2021', fontsize=25)
sns.lineplot(apple.index,apple.High, color='m');
# Out:
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
microsoft = pd.read_csv('MSFT.csv')
microsoft['Date'] = pd.to_datetime(microsoft['Date'])
microsoft.set_index('Date',inplace=True)
microsoft.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-10-06  208.820007  210.179993  204.820007  205.910004  204.037750
# 2020-10-07  207.059998  210.110001  206.720001  209.830002  207.922119
# 2020-10-08  210.509995  211.190002  208.320007  210.580002  208.665283
# 2020-10-09  211.229996  215.860001  211.229996  215.809998  213.847717
# 2020-10-12  218.789993  223.860001  216.809998  221.399994  219.386902
#
#               Volume
# Date
# 2020-10-06  28554300
# 2020-10-07  25681100
# 2020-10-08  19925800
# 2020-10-09  26458000
# 2020-10-12  40461400

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
plt.title('Microsoft History 2020-2021', fontsize=25)
sns.lineplot(microsoft.index,microsoft.High, color='c');
# Out:
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
amazon = pd.read_csv('AMZN.csv')
amazon['Date'] = pd.to_datetime(amazon['Date'])
amazon.set_index('Date',inplace=True)
amazon.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-10-06  3165.000000  3182.000000  3090.000000  3099.959961  3099.959961
# 2020-10-07  3135.000000  3200.000000  3132.389893  3195.689941  3195.689941
# 2020-10-08  3224.989990  3233.290039  3174.989990  3190.550049  3190.550049
# 2020-10-09  3210.000000  3288.989990  3197.830078  3286.649902  3286.649902
# 2020-10-12  3349.939941  3496.239990  3339.550049  3442.929932  3442.929932
#
#              Volume
# Date
# 2020-10-06  5086900
# 2020-10-07  4309400
# 2020-10-08  3174100
# 2020-10-09  4907900
# 2020-10-12  8364200

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
plt.title('Amazon History 2020-2021', fontsize=25)
sns.lineplot(amazon.index,amazon.High, color='y');
# Out:
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
history = pd.DataFrame()
history['Amazon'] = amazon['High']
history['Apple'] = apple['High']
history['Google'] = google['High']
history['Microsoft'] = microsoft['High']
history
# Out:
#                  Amazon       Apple       Google   Microsoft
# Date
# 2020-10-06  3182.000000  116.120003  1486.760010  210.179993
# 2020-10-07  3200.000000  115.550003  1468.959961  210.110001
# 2020-10-08  3233.290039  116.400002  1490.000000  211.190002
# 2020-10-09  3288.989990  117.000000  1516.520020  215.860001
# 2020-10-12  3496.239990  125.180000  1593.859985  223.860001
# ...                 ...         ...          ...         ...
# 2021-09-30  3327.850098  144.380005  2711.800049  287.829987
# 2021-10-01  3309.169922  142.919998  2741.419922  289.980011
# 2021-10-04  3279.989990  142.210007  2714.000000  287.750000
# 2021-10-05  3260.729980  142.240005  2747.239990  290.399994
# 2021-10-06  3264.340088  142.149994  2757.000000  293.630005
#
# [253 rows x 4 columns]

# %%
history = history.resample('D').sum()
history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2020-10-06 to 2021-10-06
# Freq: D
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Amazon     366 non-null    float64
#  1   Apple      366 non-null    float64
#  2   Google     366 non-null    float64
#  3   Microsoft  366 non-null    float64
# dtypes: float64(4)
# memory usage: 14.3 KB

# %%
for i in range(len(history)):
    if history['Amazon'][i]==0:
        history['Amazon'][i] =history['Amazon'][i-1]
        history['Apple'][i] =history['Apple'][i-1]
        history['Google'][i] =history['Google'][i-1]
        history['Microsoft'][i] =history['Microsoft'][i-1]

history
# Out:
#                  Amazon       Apple       Google   Microsoft
# Date
# 2020-10-06  3182.000000  116.120003  1486.760010  210.179993
# 2020-10-07  3200.000000  115.550003  1468.959961  210.110001
# 2020-10-08  3233.290039  116.400002  1490.000000  211.190002
# 2020-10-09  3288.989990  117.000000  1516.520020  215.860001
# 2020-10-10  3288.989990  117.000000  1516.520020  215.860001
# ...                 ...         ...          ...         ...
# 2021-10-02  3309.169922  142.919998  2741.419922  289.980011
# 2021-10-03  3309.169922  142.919998  2741.419922  289.980011
# 2021-10-04  3279.989990  142.210007  2714.000000  287.750000
# 2021-10-05  3260.729980  142.240005  2747.239990  290.399994
# 2021-10-06  3264.340088  142.149994  2757.000000  293.630005
#
# [366 rows x 4 columns]

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
#plt.title('Google History 2020-2021', fontsize=25)

history[['Amazon','Google']].plot(figsize=[15, 6]);
#sns.lineplot(google.index,google.High, color='c');
plt.title('Amazon and Google History 2020-2021', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Amazon and Google History 2020-2021')

# %%
history[['Apple','Microsoft']].plot(figsize=[15, 6])
plt.title('Apple and Microsoft History 2020-2021', fontsize=25);

# %%
decomposition_amazon = sm.tsa.seasonal_decompose(history.Amazon, model='additive')
decomposition_google = sm.tsa.seasonal_decompose(history.Google, model='additive')
decomposition_apple = sm.tsa.seasonal_decompose(history.Apple, model='additive')
decomposition_microsoft = sm.tsa.seasonal_decompose(history.Microsoft, model='additive')

# %%
fig = decomposition_amazon.plot()
plt.rcParams.update({'figure.figsize': (15,10)})

plt.show();

# %%
fig = decomposition_google.plot()
plt.rcParams.update({'figure.figsize': (15,10)})
plt.show();

# %%
fig = decomposition_apple.plot()
plt.rcParams.update({'figure.figsize': (15,10)})
plt.show();

# %%
fig = decomposition_microsoft.plot()
plt.rcParams.update({'figure.figsize': (15,10)})
plt.show();

# %%
train = 300
history_train = history[:train]
history_test = history[train:]
history_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 300 entries, 2020-10-06 to 2021-08-01
# Freq: D
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Amazon     300 non-null    float64
#  1   Apple      300 non-null    float64
#  2   Google     300 non-null    float64
#  3   Microsoft  300 non-null    float64
# dtypes: float64(4)
# memory usage: 11.7 KB

# %%
def holt_winters_forecasting(data,name,periods, t_s):
    train = 300
    test = 366 - train
    data_train = data[:train]
    data_test = data[train:]
    
    fitted_model = ExponentialSmoothing(data_train,trend=t_s, seasonal=t_s, seasonal_periods=periods).fit()
    test_predictions = fitted_model.forecast(test)
    
    sns.set_style("darkgrid")
    sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
    #data_train.plot(legend=True,label='TRAIN')
    #data_test.plot(legend=True,label='TEST',figsize=(15,6))
    #test_predictions.plot(legend=True,label='PREDICTION')
    #plt.title(f'{name}: Train, Test and Predicted Test using Holt Winters');

    data_test.plot(legend=True,label='TEST',figsize=(9,6))
    data_train.plot(legend=True,label='TRAIN',figsize=(9,6),xlim=['2021-06-02','2021-10-06'])
    test_predictions.plot(legend=True,label='PREDICTION',xlim=['2021-07-02','2021-10-06'])
    plt.title(f'ZOOM {name}: Train, Test and Predicted Test using Holt Winters');
    
    print(f'Mean Absolute Error = {mean_absolute_error(data_test,test_predictions)}')
    print(f'Mean Squared Error = {mean_squared_error(data_test,test_predictions)}')
    
    return test_predictions

# %%
apple_prediction = holt_winters_forecasting(history.Apple, 'Apple', 42, 'add')
# Out:
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)
# Mean Absolute Error = 3.566619962628818
# Mean Squared Error = 22.46097519972151

# %%
amazon_prediction = holt_winters_forecasting(history.Amazon,'Amazon', 44, 'mul')
# Out:
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\holtwinters\model.py:80: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)
# Mean Absolute Error = 100.57775196022591
# Mean Squared Error = 20712.023765071634

# %%
google_prediction = holt_winters_forecasting(history.Google,'Google', 44, 'add')
# Out:
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)
# Mean Absolute Error = 62.81358231159327
# Mean Squared Error = 7504.135930354274

# %%
microsoft_prediction = holt_winters_forecasting(history.Microsoft,'Microsoft', 42, 'add')
# Out:
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# c:\users\perla\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)
# Mean Absolute Error = 5.834261927063418
# Mean Squared Error = 54.57927730961083

# %%
#apple_proyect = pd.DataFrame()
history['Predicción_Amazon'] = amazon_prediction
history['Predicción_Apple'] = apple_prediction
history['Predicción_Google'] = google_prediction
history['Predicción_Microsoft'] = microsoft_prediction
predictions = history[300:]
predictions
# Out:
#                  Amazon       Apple       Google   Microsoft  \
# Date
# 2021-08-02  3358.919922  146.949997  2720.409912  286.769989
# 2021-08-03  3391.000000  148.039993  2726.709961  287.230011
# 2021-08-04  3388.879883  147.789993  2730.760010  287.589996
# 2021-08-05  3389.000000  147.839996  2739.000000  289.630005
# 2021-08-06  3375.000000  147.110001  2741.601074  289.500000
# ...                 ...         ...          ...         ...
# 2021-10-02  3309.169922  142.919998  2741.419922  289.980011
# 2021-10-03  3309.169922  142.919998  2741.419922  289.980011
# 2021-10-04  3279.989990  142.210007  2714.000000  287.750000
# 2021-10-05  3260.729980  142.240005  2747.239990  290.399994
# 2021-10-06  3264.340088  142.149994  2757.000000  293.630005
#
#             Predicción_Amazon  Predicción_Apple  Predicción_Google  \
# Date
# 2021-08-02        3356.037490        147.212812        2714.894986
# 2021-08-03        3351.615568        146.251302        2726.839442
# ...

# %%
history.to_excel('Stocks_prediction.xlsx')

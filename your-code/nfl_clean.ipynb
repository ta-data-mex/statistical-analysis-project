# %%
import numpy as np
import pandas as pd

# %%
Passing_Offense = pd.read_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Passing_Offense.csv')
Scoring_Offense = pd.read_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Scoring_Offense.csv')
Rushing_Offense = pd.read_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Rushing_Offense.csv')
Passing_Deffense = pd.read_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Paasing_Deff.csv')
Rushing_Deffense = pd.read_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Rushing_Deff.csv')
Scoring_Deffense  = pd.read_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Scoring_Deff.csv')
Fumbles = pd.read_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Fumbles.csv')
Interceptions = pd.read_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Interceptions.csv')

# %%
nfl_df = [Passing_Offense,Scoring_Offense,Rushing_Offense,Passing_Deffense,Rushing_Deffense,
         Scoring_Deffense, Fumbles,Interceptions]

for i in nfl_df:
    i.drop('Unnamed: 0', inplace=True, axis = 1) 
    i.columns = i.columns.str.strip()
    i.columns = i.columns.str.replace(' ', '_')
    
    if 'Lng' in i.columns:
        i['Lng'] = i['Lng'].str.replace('T','')
        i['Lng'] = np.floor(pd.to_numeric(i['Lng'], errors='coerce')).astype('int64')
    
    k = 0
    for j in i['Team']:
        j = str(j)
        re_list = (re.findall(r"[A-Z][^A-Z].+?[A-Z]|[0-9][0-9].+?[0-9]" , j))
        i['Team'][k] = re_list[0][:-1]
        k = k+1
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_13300\3667748617.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Team'][k] = re_list[0][:-1]
# C:\Users\danie\AppData\Local\Temp\ipykernel_13300\3667748617.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Team'][k] = re_list[0][:-1]
# C:\Users\danie\AppData\Local\Temp\ipykernel_13300\3667748617.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#Passing_Offense['Lng'] = Passing_Offense['Lng'].str.replace('T','')
#Passing_Offense['Lng'] = np.floor(pd.to_numeric(Passing_Offense['Lng'], errors='coerce')).astype('Int64')
Interceptions
# Out:
#            Team  INT  INT_TD  INT_Yds  Lng  Years
# 0      Redskins   17       0      219   48   2000
# 1    Buccaneers   25       4      275   37   2000
# 2      Seahawks   17       3      300   84   2000
# 3         49ers   13       2      278   70   2000
# 4      Chargers   16       4      313   75   2000
# ..          ...  ...     ...      ...  ...    ...
# 685       Bears    8       1      135   53   2021
# 686    Panthers    9       0      103   29   2021
# 687       Bills   19       1      238   26   2021
# 688      Ravens    9       1       38   21   2021
# 689     Falcons   12       2      202   66   2021
#
# [690 rows x 6 columns]

# %%
path = r'C:\Users\danie\Documents\data_analytics_bootcamp'

Passing_Offense.to_csv(path + '\Passing_Offensec.csv')
Scoring_Offense.to_csv(path +'\Scoring_Offensec.csv')
Rushing_Offense.to_csv(path +'\Rushing_Offensec.csv')
Passing_Deffense.to_csv(path +'\Passing_Deffensec.csv')
Rushing_Deffense.to_csv(path +'\Rushing_Deffensec.csv')
Scoring_Deffense.to_csv(path +'\Scoring_Deffensec.csv')
Fumbles.to_csv(path +'\Fumblesc.csv')
Interceptions.to_csv(path +'\Interceptionsc.csv')

# %%
#import re
#text = "SteelersSteelers"
#re_list = (re.findall(r"[A-Za-z]+(?:[A-Z])" , text))
#re_list = (re.findall(r"[A-Z][^A-Z].+?[A-Z]|[0-9][0-9].+?[0-9]" , text))
#re_list[0][:-1]
# Out:
# 'Steelers'

# %%
#k = 0
#for j in i['Team']:
    #j = str(j)
    #re_list = (re.findall(r"[A-Z][^A-Z].+?[A-Z]|[0-9][0-9].+?[0-9]" , j))
    #i['Team'][k] = re_list[0][:-1]
    #k = k+1

# %% [markdown]
# # Statistics project

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
house = pd.read_csv('train.csv')
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
corrhouse = house.corrwith(house.SalePrice)

# %%
corrhouse
# Out:
# Id              -0.021917
# MSSubClass      -0.084284
# LotFrontage      0.351799
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.477493
# BsmtFinSF1       0.386420
# BsmtFinSF2      -0.011378
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# LowQualFinSF    -0.025606
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# BsmtHalfBath    -0.016844
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageYrBlt      0.486362
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# 3SsnPorch        0.044584
# ScreenPorch      0.111447
# PoolArea         0.092404
# MiscVal         -0.021190
# ...

# %% [markdown]
# # ¿Qué afecta el precio?

# %% [markdown]
# Variables seleccionadas
# 1) YearBuilt
# 2) LotArea
# 3) GarageArea
# 4) OverallCond - la condición general o evaluación
# 5) FullBath Total de baños completos
# 6) TotRmsAbvGrd - total de habitaciones (sin baños)

# %%
casas = house[["LotArea", "OverallCond", "OverallQual","TotalBsmtSF", "YearBuilt","YearRemodAdd","FullBath","GrLivArea","TotRmsAbvGrd", "GarageCars", "SalePrice"]]

# %%
casas.describe()
# Out:
#              LotArea  OverallCond    YearBuilt  YearRemodAdd     FullBath  \
# count    1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean    10516.828082     5.575342  1971.267808   1984.865753     1.565068
# std      9981.264932     1.112799    30.202904     20.645407     0.550916
# min      1300.000000     1.000000  1872.000000   1950.000000     0.000000
# 25%      7553.500000     5.000000  1954.000000   1967.000000     1.000000
# 50%      9478.500000     5.000000  1973.000000   1994.000000     2.000000
# 75%     11601.500000     6.000000  2000.000000   2004.000000     2.000000
# max    215245.000000     9.000000  2010.000000   2010.000000     3.000000
#
#          GrLivArea  TotRmsAbvGrd   GarageArea      SalePrice
# count  1460.000000   1460.000000  1460.000000    1460.000000
# mean   1515.463699      6.517808   472.980137  180921.195890
# std     525.480383      1.625393   213.804841   79442.502883
# ...

# %%
casas.isnull().sum()
# Out:
# LotArea         0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# FullBath        0
# GrLivArea       0
# TotRmsAbvGrd    0
# GarageArea      0
# SalePrice       0
# dtype: int64

# %%
casas.corr()
# Out:
#                LotArea  OverallCond  YearBuilt  YearRemodAdd  FullBath  \
# LotArea       1.000000    -0.005636   0.014228      0.013788  0.126031
# OverallCond  -0.005636     1.000000  -0.375983      0.073741 -0.194149
# YearBuilt     0.014228    -0.375983   1.000000      0.592855  0.468271
# YearRemodAdd  0.013788     0.073741   0.592855      1.000000  0.439046
# FullBath      0.126031    -0.194149   0.468271      0.439046  1.000000
# GrLivArea     0.263116    -0.079686   0.199010      0.287389  0.630012
# TotRmsAbvGrd  0.190015    -0.057583   0.095589      0.191740  0.554784
# GarageArea    0.180403    -0.151521   0.478954      0.371600  0.405656
# SalePrice     0.263843    -0.077856   0.522897      0.507101  0.560664
#
#               GrLivArea  TotRmsAbvGrd  GarageArea  SalePrice
# LotArea        0.263116      0.190015    0.180403   0.263843
# OverallCond   -0.079686     -0.057583   -0.151521  -0.077856
# YearBuilt      0.199010      0.095589    0.478954   0.522897
# ...

# %%
casas[["LotArea", "OverallCond", "OverallQual","TotalBsmtSF", "YearBuilt","YearRemodAdd","FullBath","GrLivArea","TotRmsAbvGrd", "GarageCars"]].corr()
# Out:
#                LotArea  OverallCond  OverallQual  TotalBsmtSF  YearBuilt  \
# LotArea       1.000000    -0.005636     0.105806     0.260833   0.014228
# OverallCond  -0.005636     1.000000    -0.091932    -0.171098  -0.375983
# OverallQual   0.105806    -0.091932     1.000000     0.537808   0.572323
# TotalBsmtSF   0.260833    -0.171098     0.537808     1.000000   0.391452
# YearBuilt     0.014228    -0.375983     0.572323     0.391452   1.000000
# YearRemodAdd  0.013788     0.073741     0.550684     0.291066   0.592855
# FullBath      0.126031    -0.194149     0.550600     0.323722   0.468271
# GrLivArea     0.263116    -0.079686     0.593007     0.454868   0.199010
# TotRmsAbvGrd  0.190015    -0.057583     0.427452     0.285573   0.095589
# GarageCars    0.154871    -0.185758     0.600671     0.434585   0.537850
#
#               YearRemodAdd  FullBath  GrLivArea  TotRmsAbvGrd  GarageCars
# LotArea           0.013788  0.126031   0.263116      0.190015    0.154871
# ...

# %%
#ninguna correlción es demasiado cercana a 1, no descarto ninguna

# %% [markdown]
# # Gráficas
# Gráficas hechas en tableau

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
casas.dtypes
# Out:
# LotArea         int64
# OverallCond     int64
# OverallQual     int64
# TotalBsmtSF     int64
# YearBuilt       int64
# YearRemodAdd    int64
# FullBath        int64
# GrLivArea       int64
# TotRmsAbvGrd    int64
# GarageCars      int64
# SalePrice       int64
# dtype: object

# %%
x_casas = sm.add_constant(casas[["LotArea", "OverallCond", "OverallQual","TotalBsmtSF", "YearBuilt","YearRemodAdd","GrLivArea", "GarageCars"]])
y_casas = casas["SalePrice"]

# %%
casas.LotArea.corr(casas.SalePrice, method="pearson")
# Out:
# 0.26384335387140573

# %%
casas.OverallCond.corr(casas.SalePrice, method="pearson")
# Out:
# -0.07785589404867801

# %%
housemodel = sm.OLS(y_casas, x_casas).fit()
predictions = housemodel.predict()

print_model = housemodel.summary()
print_model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.782
# Model:                            OLS   Adj. R-squared:                  0.780
# Method:                 Least Squares   F-statistic:                     649.4
# Date:                Sat, 11 Jan 2020   Prob (F-statistic):               0.00
# Time:                        13:41:48   Log-Likelihood:                -17433.
# No. Observations:                1460   AIC:                         3.488e+04
# Df Residuals:                    1451   BIC:                         3.493e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
